# %%
import os
import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import rasterio
import rasterio.features
import geopandas as gpd
import math
from shapely.geometry import shape
from datetime import datetime
from pytz import timezone, utc
from matplotlib.colors import ListedColormap, LinearSegmentedColormap, Normalize
import matplotlib.patches as patches

# --- Parameters ---
original_root = '/Volumes/External/TJ_SAR/02_preprocessed/background_gooddays'
mask_root = '/Volumes/External/TJ_SAR/04_iseg/wide_gooddays'
output_plot_dir = '/05_viz/wide_gooddays'
output_shapefile_dir = '/06_shapefiles/wide_gooddays'
met_csv_path = '/Volumes/External/TJ_estuary/analysis/TJRTLMET.csv'
threshold = 0  # only keep mask values > threshold

# --- New: Path to point-data shapefile ---
point_shapefile_path = '/01_data/shapefiles/Outflow.shp'

# timezones
pacific = timezone('US/Pacific')

# --- Load meteorological data (in Pacific Time) ---
met_df = pd.read_csv(met_csv_path)
met_df.columns = met_df.columns.str.strip()
met_df['DateTimeStamp'] = pd.to_datetime(
    met_df['DateTimeStamp'], format='%m/%d/%y %H:%M', errors='coerce'
)
met_df['DateTimeStamp'] = met_df['DateTimeStamp'].dt.tz_localize(
    pacific,
    ambiguous='NaT',
    nonexistent='NaT'
)
met_df = met_df.dropna(subset=['DateTimeStamp']).sort_values('DateTimeStamp')

# --- Load point data once ---
points_gdf_orig = gpd.read_file(point_shapefile_path)

# --- Utility functions ---

def extract_datetime_from_filename(filename):
    '''Extract UTC datetime from Sentinel-1 filename.'''
    parts = filename.split('_')
    for part in parts:
        if part.startswith('20') and 'T' in part:
            try:
                return utc.localize(datetime.strptime(part, '%Y%m%dT%H%M%S'))
            except ValueError:
                continue
    return None


def get_nearest_met_data(local_time):
    '''Find the closest met record to the given local time.'''
    diffs = (met_df['DateTimeStamp'] - local_time).abs()
    idx = diffs.idxmin()
    row = met_df.loc[idx]
    return row['WSpd'], row['Wdir'], row['DateTimeStamp']


def match_original_path(mask_filename):
    return os.path.join(
        original_root,
        mask_filename.replace('_JPL0.4_VVDR_cumulative_mask.tif', '.tif')
    )

# --- Main processing loop ---
# make sure output dirs exist
os.makedirs(output_plot_dir, exist_ok=True)
os.makedirs(output_shapefile_dir, exist_ok=True)

for root, _, files in os.walk(mask_root):
    for file in files:
        if file.startswith('.') or not file.endswith('_JPL0.4_VVDR_cumulative_mask.tif'):
            continue

        mask_path = os.path.join(root, file)
        original_path = match_original_path(file)

        if not os.path.exists(original_path):
            print(f'[!] Original image not found for: {file}')
            continue

        # --- Read mask and prepare shapefile export ---
        with rasterio.open(mask_path) as src_mask:
            mask_arr = src_mask.read(1)
            transform = src_mask.transform
            crs = src_mask.crs
            nodata = src_mask.nodata

        # Build boolean mask: pixels > threshold and not nodata
        valid_mask = mask_arr > threshold
        if nodata is not None:
            valid_mask &= (mask_arr != nodata)

        # Vectorize mask to shapes
        shapes = []
        for geom, val in rasterio.features.shapes(
            mask_arr.astype('int16'),
            mask=valid_mask,
            transform=transform
        ):
            shapes.append({'geometry': shape(geom), 'value': int(val)})

        # Write GeoDataFrame if any shapes found
        if shapes:
            gdf = gpd.GeoDataFrame(shapes, crs=crs)
            shp_name = file.replace(
                '_JPL0.4_VVDR_cumulative_mask.tif', '_mask.shp'
            )
            out_shp = os.path.join(output_shapefile_dir, shp_name)
            gdf.to_file(out_shp, driver='ESRI Shapefile')
            print(f'  → wrote shapefile: {out_shp}')
        else:
            print(f'  → no valid mask pixels for: {file}, skipping shapefile.')

        # --- Read original for plotting and get meteorology ---
        image_time_utc = extract_datetime_from_filename(file)
        image_time_local = image_time_utc.astimezone(pacific)
        wspd, wdir, met_time = get_nearest_met_data(image_time_local)

        with rasterio.open(original_path) as src_orig:
            original = src_orig.read(1).astype(float)
            bounds = src_orig.bounds
            extent = [bounds.left, bounds.right, bounds.bottom, bounds.top]

        # Stretch original reflectance
        vmin, vmax = np.nanpercentile(original, (2, 95))
        clipped = np.clip(original, vmin, vmax)
        normed = (clipped - vmin) / (vmax - vmin)

        # Build RGBA overlay
        overlay = np.zeros((mask_arr.shape[0], mask_arr.shape[1], 4))
        overlay[valid_mask] = [1.0, 1.0, 0.8, 1.0]

        # --- Reproject points to match image CRS ---
        points_gdf = points_gdf_orig.to_crs(crs)

        # --- Plot ---
        fig, axes = plt.subplots(1, 2, figsize=(9, 12), constrained_layout=True)

        # left: original
        axes[0].imshow(normed, cmap='gray', extent=extent)
        points_gdf.plot(
            ax=axes[0],
            marker='o',
            color='red',
            markersize=5,
            label='Points'
        )
        axes[0].set_title('Original (2–98% Stretch)', fontsize=12)
        axes[0].axis('off')

        # right: with mask overlay
        axes[1].imshow(normed, cmap='gray', extent=extent)
        axes[1].imshow(overlay, extent=extent)
        points_gdf.plot(
            ax=axes[1],
            marker='o',
            color='red',
            markersize=5
        )
        axes[1].set_title('Original with Plume Mask', fontsize=12)
        axes[1].axis('off')

        # Annotation and wind vector
        wind_text = (
            f'Wind: {wspd:.1f} m/s @ {wdir:.0f}°\n'
            f'Local Time: {image_time_local.strftime('%Y-%m-%d %H:%M')}'
        )
        fig.text(0.5, 0.15, wind_text, ha='center', fontsize=13, fontweight='bold')
        wind_angle_deg = (270 - wdir) % 360
        angle_rad = math.radians(wind_angle_deg)
        height = bounds.top - bounds.bottom
        base_frac = 0.07
        scale = np.clip(wspd / 10, 0.5, 1.5)
        arrow_length = height * base_frac * scale
        dx = arrow_length * math.cos(angle_rad)
        dy = arrow_length * math.sin(angle_rad)
        x0 = bounds.right - 0.1 * (bounds.right - bounds.left)
        y0 = bounds.bottom + 0.05 * height
        axes[1].add_patch(
            patches.FancyArrow(
                x0, y0, dx, dy,
                width=arrow_length * 0.05,
                head_width=arrow_length * 0.15,
                head_length=arrow_length * 0.15,
                length_includes_head=True,
                transform=axes[1].transData,
                color='lime',
                alpha=0.9
            )
        )

        # Save figure
        flat_name = file.replace(
            '_JPL0.4_VVDR_cumulative_mask.tif', '_overlay.png'
        )
        out_png = os.path.join(output_plot_dir, flat_name)
        os.makedirs(os.path.dirname(out_png), exist_ok=True)
        plt.savefig(out_png, dpi=150, bbox_inches='tight')
        plt.close()
        print(f'  → saved plot: {out_png}')

print('Done!')
# Out:
# Batch complete.

# %% [markdown]
# **plot algorithm and polgyon on each base image**

# %%
import os
import pandas as pd
import geopandas as gpd
import rasterio
from rasterio.plot import show
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.patches import Patch
from matplotlib.lines import Line2D

# Paths
original_root = '/Volumes/External/TJ_SAR/02_preprocessed/background_gooddays'
shapefile_dir = '/Volumes/External/TJ_SAR/06_shapefiles/great'
plume_path = '/Volumes/External/TJ_SAR/01_data/shapefiles/plumeExtentv4.shp'
outflow_path = '/Volumes/External/TJ_SAR/01_data/shapefiles/Outflow.shp'
excel_path = '/Volumes/External/TJ_SAR/analysis/Master.xlsx'

# Load input data
df = pd.read_excel(excel_path)
plume_gdf = gpd.read_file(plume_path).to_crs(epsg=4326)
outflow_gdf = gpd.read_file(outflow_path).to_crs(epsg=4326)

# New zoom box from WKT polygon
xlim = (-117.226868, -117.03186)
ylim = (32.328917, 32.632436)


# Loop through unique basenames
for original_filename in df["original_filename"].drop_duplicates():
    base_name = original_filename
    image_path = os.path.join(original_root, f"{base_name}_pre.tif")
    shapefile_path = os.path.join(shapefile_dir, f"{base_name}_pre_mask.shp")

    # Check image and shapefile exist
    if not os.path.exists(image_path):
        print(f"Image not found: {image_path}")
        continue
    if not os.path.exists(shapefile_path):
        print(f"Shapefile not found: {shapefile_path}")
        continue

    # Find matching manual delineations (plume)
    matching_plume = plume_gdf[plume_gdf["sourceName"] == base_name]

    # Start plot
    with rasterio.open(image_path) as src:
        img = src.read(1).astype(np.float32)
        mask = img > 0
        vmin, vmax = np.percentile(img[mask], (3, 90))

        fig, ax = plt.subplots(figsize=(10, 10))
        show(img, ax=ax, transform=src.transform, cmap='gray', vmin=vmin, vmax=vmax)
        ax.set_title(base_name)

        # Plot red: algorithm output
        gdf = gpd.read_file(shapefile_path)
        gdf.plot(ax=ax, facecolor='none', edgecolor='red', linewidth=1, zorder=2)

        # Plot blue dashed: manual delineation
        if not matching_plume.empty:
            matching_plume.plot(ax=ax, facecolor='none', edgecolor='deepskyblue', linewidth=1.5,
                                linestyle='--', zorder=3)

        # Plot yellow: outflow points
        outflow_gdf.plot(ax=ax, color='yellow', edgecolor='black',  markersize=25, zorder=4)

        # Cropping and cleanup
        ax.set_xlim(*xlim)
        ax.set_ylim(*ylim)
        ax.grid(False)

        # Legend
        legend_elements = [
            Patch(facecolor='none', edgecolor='red', label='algorithm output'),
            Line2D([0], [0], color='deepskyblue', linestyle='--', label='manual delineation'),
            Line2D([0], [0], marker='o', color='yellow', markeredgecolor='black', linestyle='None', markersize=8, label='outflow points')
        ]
        ax.legend(handles=legend_elements, loc='upper right', fontsize='medium', frameon=True)

        # Save figure
        output_dir = "/Volumes/External/TJ_SAR/05_viz/algovspolygon"
        os.makedirs(output_dir, exist_ok=True)
        output_path = os.path.join(output_dir, f"{base_name}.png")
        plt.savefig(output_path, dpi=300, bbox_inches='tight')
        plt.close()
# Out:
# Shapefile not found: /Volumes/External/TJ_SAR/06_shapefiles/great/S1A_IW_GRDH_1SDV_20230917T015020_20230917T015049_050361_06103C_F092_pre_mask.shp
# Shapefile not found: /Volumes/External/TJ_SAR/06_shapefiles/great/S1A_IW_GRDH_1SDV_20240303T015016_20240303T015045_052811_066417_AE29_pre_mask.shp
# Image not found: /Volumes/External/TJ_SAR/02_preprocessed/background_gooddays/S1A_IW_GRDH_1SDV_20240315T135319_20240315T135344_052993_066A5F_CBC10_pre.tif
# Shapefile not found: /Volumes/External/TJ_SAR/06_shapefiles/great/S1A_IW_GRDH_1SDV_20240403T134457_20240403T134522_053270_0674E8_A9EF_pre_mask.shp
# Shapefile not found: /Volumes/External/TJ_SAR/06_shapefiles/great/S1A_IW_GRDH_1SDV_20240825T134455_20240825T134520_055370_06C0B3_2887_pre_mask.shp

# %% [markdown]
# **This script processes each shapefile in a given folder, determines which outflow point (PB or TJ)
# each feature is closest to, and merges features by nearest outflow. The result is saved as new
# shapefiles with "_algo_PB" or "_algo_TJ" suffixes. All distance calculations are performed in
# UTM Zone 11N (EPSG:32611) for spatial accuracy.**

# %%
import geopandas as gpd
from shapely.ops import unary_union
from shapely.geometry import MultiPolygon
import os

# Paths
input_dir = "/Volumes/External/TJ_SAR/06_shapefiles/great"
outflow_path = "/Volumes/External/TJ_SAR/01_data/shapefiles/Outflow.shp"
output_dir = "/Volumes/External/TJ_SAR/06_shapefiles/algorithmOutputperStudyArea"

# UTM Zone 11N (Southern California)
projected_crs = "EPSG:32611"

# Load and project outflow points
print(f"Loading outflow points from: {outflow_path}")
outflow_gdf = gpd.read_file(outflow_path)
outflow_gdf = outflow_gdf.to_crs(projected_crs)
print(f"Loaded {len(outflow_gdf)} outflow points (projected to {projected_crs}).")

# Get list of valid shapefiles to process
shapefiles = [
    f for f in os.listdir(input_dir)
    if f.endswith(".shp") and not f.startswith("._")
]
print(f"Found {len(shapefiles)} shapefiles to process in '{input_dir}'.")

for shp_name in shapefiles:
    input_path = os.path.join(input_dir, shp_name)
    print(f"\nProcessing shapefile: {shp_name}")
    gdf = gpd.read_file(input_path)
    gdf = gdf.to_crs(projected_crs)  # Project to UTM

    print(f"  Number of features in shapefile: {len(gdf)}")

    # Map to store features closest to PB or TJ
    grouped_features = {"PB": [], "TJ": []}

    for i, feature in gdf.iterrows():
        geom = feature.geometry
        distances = outflow_gdf.geometry.distance(geom)
        nearest_idx = distances.idxmin()
        nearest_label = outflow_gdf.loc[nearest_idx, "featureNam"]
        print(f"    Feature {i} is closest to: {nearest_label}")

        if nearest_label in grouped_features:
            grouped_features[nearest_label].append(geom)

    base_name = os.path.splitext(shp_name)[0]

    # Save merged features
    for label, features in grouped_features.items():
        if not features:
            print(f"  No features closest to {label}, skipping.")
            continue
        merged_geom = unary_union(features)
        if not isinstance(merged_geom, MultiPolygon):
            merged_geom = MultiPolygon([merged_geom])

        merged_gdf = gpd.GeoDataFrame({"geometry": [merged_geom]}, crs=projected_crs)
        output_name = f"{base_name}_algo_{label}.shp"
        output_path = os.path.join(output_dir, output_name)
        merged_gdf.to_file(output_path)
        print(f"  Saved merged {label} geometry to: {output_path}")

print("\nAll shapefiles processed successfully.")
# Out:
# Loading outflow points from: /Volumes/External/TJ_SAR/01_data/shapefiles/Outflow.shp
# Loaded 2 outflow points (projected to EPSG:32611).
# Found 27 shapefiles to process in '/Volumes/External/TJ_SAR/06_shapefiles/great'.
#
# Processing shapefile: S1A_IW_GRDH_1SDV_20250509T015010_20250509T015039_059111_07557C_D41A_pre_mask.shp
#   Number of features in shapefile: 3
#     Feature 0 is closest to: TJ
#     Feature 1 is closest to: TJ
#     Feature 2 is closest to: PB
#   Saved merged PB geometry to: /Volumes/External/TJ_SAR/06_shapefiles/algorithmOutputperStudyArea/S1A_IW_GRDH_1SDV_20250509T015010_20250509T015039_059111_07557C_D41A_pre_mask_algo_PB.shp
#   Saved merged TJ geometry to: /Volumes/External/TJ_SAR/06_shapefiles/algorithmOutputperStudyArea/S1A_IW_GRDH_1SDV_20250509T015010_20250509T015039_059111_07557C_D41A_pre_mask_algo_TJ.shp
#
# Processing shapefile: S1C_IW_GRDH_1SDV_20250421T014857_20250421T014922_001985_003FBB_DFC0_pre_mask.shp
#   Number of features in shapefile: 4
# ...

# %%
import geopandas as gpd
import os
from shapely.geometry import Polygon
from shapely.ops import unary_union
import numpy as np

# Paths
obs_path = "/Volumes/External/TJ_SAR/01_data/shapefiles/plumeExtentv4.shp"
pred_base_path = "/Volumes/External/TJ_SAR/06_shapefiles/algorithmOutputperStudyArea"

# Load observed shapefile
print(f"Loading observed shapefile from:\n  {obs_path}")
obs_gdf = gpd.read_file(obs_path)
print(f"Total observed features: {len(obs_gdf)}")

# Store IoUs
ious = []
missing = []

# Iterate through observed features
for idx, row in obs_gdf.iterrows():
    name = f"{row['sourceName']}_pre_mask_algo_{row['outflow']}"
    pred_path = os.path.join(pred_base_path, f"{name}.shp")

    print(f"\nProcessing feature {idx + 1}/{len(obs_gdf)}:")
    print(f"  Expected predicted shapefile: {pred_path}")

    if os.path.exists(pred_path):
        print(f"  ✔ Found predicted shapefile.")

        try:
            pred_gdf = gpd.read_file(pred_path)

            # Validate geometries
            obs_geom = row.geometry
            pred_geoms = pred_gdf.geometry

            if not obs_geom.is_valid:
                print(f"  ⚠ Observed geometry invalid. Attempting unary_union for cleanup.")
            obs_geom = unary_union([obs_geom])

            valid_pred_geoms = [geom for geom in pred_geoms if geom.is_valid]
            if not valid_pred_geoms:
                print(f"  ⚠ All predicted geometries invalid or empty. Skipping.")
                continue

            pred_geom = unary_union(valid_pred_geoms)

            # Compute intersection and union
            intersection = obs_geom.intersection(pred_geom).area
            union = obs_geom.union(pred_geom).area

            print(f"  Intersection area: {intersection:.4f}")
            print(f"  Union area: {union:.4f}")

            if union > 0:
                iou = intersection / union
                ious.append(iou)
                print(f"  ✅ IoU: {iou:.4f}")
            else:
                print(f"  ⚠ Union area is zero. Skipping IoU computation.")
        except Exception as e:
            print(f"  ❌ Error processing {name}: {e}")
    else:
        print(f"  ❌ Predicted shapefile not found for: {name}")
        missing.append(name)

# Output summary
print("\n========== SUMMARY ==========")
if ious:
    print(f"✔ IoU computed for {len(ious)} feature pairs.")
    print(f"Mean IoU: {np.mean(ious):.4f}")
    print(f"Median IoU: {np.median(ious):.4f}")
else:
    print("❌ No IoUs computed.")

if missing:
    print(f"\nMissing predictions for {len(missing)} features:")
    for name in missing:
        print(f"  - {name}")
# Out:
# Loading observed shapefile from:
#   /Volumes/External/TJ_SAR/01_data/shapefiles/plumeExtentv4.shp
# Total observed features: 65
#
# Processing feature 1/65:
#   Expected predicted shapefile: /Volumes/External/TJ_SAR/06_shapefiles/algorithmOutputperStudyArea/S1A_IW_GRDH_1SDV_20241216T015014_20241216T015043_057011_070161_E8F2_pre_mask_algo_PB.shp
#   ✔ Found predicted shapefile.
#   Intersection area: 418105.5367
#   Union area: 2219405.5808
#   ✅ IoU: 0.1884
#
# Processing feature 2/65:
#   Expected predicted shapefile: /Volumes/External/TJ_SAR/06_shapefiles/algorithmOutputperStudyArea/S1A_IW_GRDH_1SDV_20240930T134456_20240930T134521_055895_06D520_6A0F_pre_mask_algo_PB.shp
#   ❌ Predicted shapefile not found for: S1A_IW_GRDH_1SDV_20240930T134456_20240930T134521_055895_06D520_6A0F_pre_mask_algo_PB
#
# Processing feature 3/65:
# ...

# %%
from pathlib import Path  # ✅ Add this line
# Updated path to observed shapefile
obs_path = "/Volumes/External/TJ_SAR/01_data/shapefiles/plumeExtentv4.shp"
pred_base_path = "/Volumes/External/TJ_SAR/06_shapefiles/algorithmOutputperStudyArea"

# Load observed shapefile
obs_gdf = gpd.read_file(obs_path)

# Store IoUs and metadata
results = []

# Iterate through observed features
for idx, row in obs_gdf.iterrows():
    name = f"{row['sourceName']}_pre_mask_algo_{row['outflow']}"
    pred_path = os.path.join(pred_base_path, f"{name}.shp")

    if os.path.exists(pred_path):
        try:
            pred_gdf = gpd.read_file(pred_path)
            obs_geom = unary_union([row.geometry])
            pred_geom = unary_union([geom for geom in pred_gdf.geometry if geom.is_valid])

            intersection = obs_geom.intersection(pred_geom).area
            union = obs_geom.union(pred_geom).area
            iou = intersection / union if union > 0 else 0

            results.append({
                "index": idx + 1,
                "name": name,
                "obs_geom": obs_geom,
                "pred_geom": pred_geom,
                "iou": iou
            })
        except Exception as e:
            continue

# Create plots
figures = []
output_dir = "/Volumes/External/TJ_SAR/05_viz/IoUplots"
Path(output_dir).mkdir(parents=True, exist_ok=True)

# Save IoU overlay plots
for result in results:
    import matplotlib.patches as mpatches

    # Inside your loop:
    fig, ax = plt.subplots()
    gpd.GeoSeries(result["obs_geom"]).plot(ax=ax, color="blue", alpha=0.5)
    gpd.GeoSeries(result["pred_geom"]).plot(ax=ax, color="red", alpha=0.5)

    # Custom legend handles
    obs_patch = mpatches.Patch(color='blue', alpha=0.5, label='Observed')
    pred_patch = mpatches.Patch(color='red', alpha=0.5, label='Predicted')
    plt.legend(handles=[obs_patch, pred_patch])

    plt.title(f"{result['name']}\nIoU: {result['iou']:.4f}")
    plot_path = os.path.join(output_dir, f"{result['index']:02d}_{result['name']}_iou.png")
    plt.savefig(plot_path)
    plt.close()


# Create DataFrame
iou_df = pd.DataFrame(results)[["index", "name", "iou"]]
iou_df.sort_values(by="index", inplace=True)

# Drop NaN values and compute statistics
valid_ious = iou_df["iou"].dropna()
mean_iou = valid_ious.mean()
median_iou = valid_ious.median()

# Print stats
print(f"\nMean IoU: {mean_iou:.4f}")
print(f"Median IoU: {median_iou:.4f}")

# Output CSV
output_csv_path = os.path.join(output_dir, "iou_summary.csv")
iou_df.to_csv(output_csv_path, index=False)
print(f"IoU results written to: {output_csv_path}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 7
#       4 pred_base_path = "/Volumes/External/TJ_SAR/06_shapefiles/algorithmOutputperStudyArea"
#       6 # Load observed shapefile
# ----> 7 obs_gdf = gpd.read_file(obs_path)
#       9 # Store IoUs and metadata
#      10 results = []
#
# NameError: name 'gpd' is not defined

# %% [markdown]
# ** plot algorithm vs manual and add IoU to plot**

# %%
import os
from pathlib import Path
import geopandas as gpd
import rasterio
from rasterio.plot import show
import matplotlib.pyplot as plt
from shapely.ops import unary_union
from matplotlib.patches import Patch
from matplotlib.lines import Line2D
import pandas as pd
import numpy as np

# Paths
original_root = "/Volumes/External/TJ_SAR/02_preprocessed/background_gooddays"
obs_path = "/Volumes/External/TJ_SAR/01_data/shapefiles/plumeExtentv4.shp"
pred_base_path = "/Volumes/External/TJ_SAR/06_shapefiles/algorithmOutputperStudyArea"
outflow_path = "/Volumes/External/TJ_SAR/01_data/shapefiles/Outflow.shp"
output_dir = "/Volumes/External/TJ_SAR/05_viz/comparativePlots"

Path(output_dir).mkdir(parents=True, exist_ok=True)

# Load shapefiles
obs_gdf = gpd.read_file(obs_path)
outflow_gdf = gpd.read_file(outflow_path)

# Get Sentinel-1 _pre.tif files
tif_files = [f for f in os.listdir(original_root) if f.endswith("_pre.tif")]

results = []

for tif_file in tif_files:
    base_name = tif_file.replace("_pre.tif", "")
    raster_path = os.path.join(original_root, tif_file)

    print(f"\nProcessing: {base_name}")

    # Match observed features
    matched_obs = obs_gdf[obs_gdf["sourceName"] == base_name]
    if matched_obs.empty:
        print(f"  ⚠ No observed features found for: {base_name}")
        continue

    # Match outflow points
    matched_outflows = outflow_gdf[outflow_gdf["sourceName"] == base_name]

    # Match predicted shapefiles
    pred_matches = []
    for algo in ["PB", "TJ"]:
        pred_shp = os.path.join(pred_base_path, f"{base_name}_pre_mask_algo_{algo}.shp")
        if os.path.exists(pred_shp):
            try:
                pred_gdf = gpd.read_file(pred_shp)
                pred_geom = unary_union([geom for geom in pred_gdf.geometry if geom.is_valid and not geom.is_empty])
                pred_matches.append((algo, pred_geom))
            except Exception as e:
                print(f"  ❌ Failed to read or process {pred_shp}: {e}")
        else:
            print(f"  ⚠ Predicted shapefile not found for {algo}")

    if not pred_matches:
        print("  ❌ No valid predicted shapefiles found. Skipping.")
        continue

    # Combine observed geometries
    obs_geom = unary_union([geom for geom in matched_obs.geometry if geom.is_valid and not geom.is_empty])

    # Start plotting
    with rasterio.open(raster_path) as src:
        fig, ax = plt.subplots(figsize=(10, 10))
        show(src, ax=ax, title=base_name)

        # Plot observed polygon
        gpd.GeoSeries(obs_geom).boundary.plot(ax=ax, color='deepskyblue', linestyle='--')

        # Plot outflow points
        if not matched_outflows.empty:
            matched_outflows.plot(ax=ax, color='yellow', marker='o', markersize=30)

        # Plot and evaluate predictions
        for algo, pred_geom in pred_matches:
            gpd.GeoSeries(pred_geom).boundary.plot(ax=ax, edgecolor='red')

            # IoU computation
            intersection = obs_geom.intersection(pred_geom).area
            union = obs_geom.union(pred_geom).area
            iou = intersection / union if union > 0 else np.nan
            results.append({
                "scene": base_name,
                "algorithm": algo,
                "iou": iou
            })
            print(f"  ✅ IoU ({algo}): {iou:.4f}")

        # Legend
        legend_elements = [
            Patch(facecolor='none', edgecolor='red', label='algorithm output'),
            Line2D([0], [0], color='deepskyblue', linestyle='--', label='manual delineation'),
            Line2D([0], [0], marker='o', color='yellow', linestyle='None', markersize=8, label='outflow points')
        ]
        ax.legend(handles=legend_elements, loc='upper right', fontsize='medium', frameon=True)

        # Save plot
        plot_path = os.path.join(output_dir, f"{base_name}_overlay.png")
        plt.savefig(plot_path)
        plt.close()
        print(f"  📸 Saved plot: {plot_path}")

# Save IoU results
iou_df = pd.DataFrame(results)
csv_path = os.path.join(output_dir, "iou_summary.csv")
iou_df.to_csv(csv_path, index=False)

# Print summary
if not iou_df.empty:
    mean_iou = iou_df["iou"].mean()
    median_iou = iou_df["iou"].median()
    print(f"\n📊 IoU Summary for {len(iou_df)} scenes:")
    print(f"  Mean IoU: {mean_iou:.4f}")
    print(f"  Median IoU: {median_iou:.4f}")
    print(f"  Results written to: {csv_path}")
else:
    print("❌ No IoUs were computed. Check for matching inputs.")
# Out:
# Processing: S1A_IW_GRDH_1SDV_20221203T015015_20221203T015044_046161_0586BC_72DC
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/RS/lib/python3.13/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'sourceName'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
import rasterio
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.cm import get_cmap
from rasterio.mask import mask
from shapely.geometry import Polygon, mapping, box
from shapely.ops import transform
from pyproj import Transformer

# Define polygon in WGS84
polygon_wgs84 = Polygon([
    (-117.209015, 32.373003),
    (-117.066193, 32.373003),
    (-117.066193, 32.604675),
    (-117.209015, 32.604675),
    (-117.209015, 32.373003)
])

# Input file paths
tif_paths = [
    '/Volumes/External/TJ_SAR/02_preprocessed/background_gooddays/S1A_IW_GRDH_1SDV_20240911T135318_20240911T135343_055618_06CA33_3AB0_pre.tif',
    '/Volumes/External/TJ_Optical/images/RGB_2024-09-11.tif',
    '/Volumes/External/TJ_Optical/images/NDTI_2024-09-11.tif',
    '/Volumes/External/TJ_Optical/images/NDCI_2024-09-11.tif'
]

# 5–95% stretch
def scale_image(img):
    p5, p95 = np.percentile(img, (5, 95))
    return np.clip((img - p5) / (p95 - p5 + 1e-6), 0, 1)

# Store images (or None on failure)
images = []

# Debug and clip
for path in tif_paths:
    print(f"\n🟡 Checking: {path}")
    with rasterio.open(path) as src:
        print(f" - CRS: {src.crs}")
        print(f" - Bounds: {src.bounds}")
        print(f" - Band count: {src.count}")

        # Transform image bounds to WGS84 for intersection check
        bbox = box(*src.bounds)
        transformer = Transformer.from_crs(src.crs, "EPSG:4326", always_xy=True)
        bbox_wgs84 = transform(transformer.transform, bbox)

        intersects = polygon_wgs84.intersects(bbox_wgs84)
        print(f" - Intersects AOI polygon: {intersects}")

        if not intersects:
            print("   ⚠️ Image does not intersect AOI — skipping.")
            images.append(None)
            continue

        # Transform polygon to image CRS for clipping
        transformer_to_img = Transformer.from_crs("EPSG:4326", src.crs, always_xy=True)
        polygon_img = transform(transformer_to_img.transform, polygon_wgs84)
        geojson_geom = [mapping(polygon_img)]

        # Try to clip
        try:
            clipped, _ = mask(src, geojson_geom, crop=True)
            if clipped.size == 0 or np.all(clipped == 0):
                raise ValueError("Clipped result is empty or all zeros.")
            print(f"   ✅ Clipped shape: {clipped.shape}, min: {clipped.min()}, max: {clipped.max()}")
            images.append(clipped)
        except Exception as e:
            print(f"   ❌ Failed to clip: {e}")
            images.append(None)

# Plotting
fig, axes = plt.subplots(1, 4, figsize=(20, 5))

titles = ["Grayscale", "RGB", "Viridis 3", "Viridis 4"]

for i, (img, ax, title) in enumerate(zip(images, axes, titles)):
    ax.axis('off')
    if img is None:
        ax.set_title(f"{title} (No data)")
        continue

    try:
        if i == 0:  # Grayscale
            ax.imshow(scale_image(img[0]), cmap='gray')
        elif i == 1:  # RGB
            if img.shape[0] < 3:
                raise ValueError("Not enough bands for RGB")
            rgb = np.stack([scale_image(img[0]), scale_image(img[1]), scale_image(img[2])], axis=-1)
            ax.imshow(rgb)
        else:  # Viridis
            ax.imshow(scale_image(img[0]), cmap='viridis')
        ax.set_title(title)
    except Exception as e:
        print(f"⚠️ Plotting error on {title}: {e}")
        ax.set_title(f"{title} (Error)")

plt.tight_layout()
plt.show()
# Out:
# 🟡 Checking: /Volumes/External/TJ_SAR/02_preprocessed/background_gooddays/S1A_IW_GRDH_1SDV_20240911T135318_20240911T135343_055618_06CA33_3AB0_pre.tif
#  - CRS: EPSG:4326
#  - Bounds: BoundingBox(left=-117.45761208808543, bottom=32.268442519572446, right=-117.00701714157107, top=32.724966346961985)
#  - Band count: 2
#  - Intersects AOI polygon: True
#    ✅ Clipped shape: (2, 1291, 796), min: nan, max: nan
#
# 🟡 Checking: /Volumes/External/TJ_Optical/images/RGB_2024-09-11.tif
#  - CRS: EPSG:4326
#  - Bounds: BoundingBox(left=-117.4191501133763, bottom=32.324258531529566, right=-116.99882839193678, top=32.75976178127071)
#  - Band count: 3
#  - Intersects AOI polygon: True
#    ✅ Clipped shape: (3, 2580, 1591), min: 0, max: 12272
#
# 🟡 Checking: /Volumes/External/TJ_Optical/images/NDTI_2024-09-11.tif
#  - CRS: EPSG:4326
#  - Bounds: BoundingBox(left=-117.4191501133763, bottom=32.324258531529566, right=-116.99882839193678, top=32.75976178127071)
#  - Band count: 1
# ...

# %%
import rasterio
import numpy as np
import matplotlib.pyplot as plt
import geopandas as gpd
from rasterio.mask import mask
from shapely.geometry import mapping, box
from shapely.ops import transform
from shapely import wkt
from pyproj import Transformer
import os
import re
from datetime import datetime
from matplotlib.cm import ScalarMappable
from matplotlib.colors import Normalize

# 📌 Paste your polygon WKT string here
polygon_wkt = "POLYGON ((-117.284546 32.379961, -117.077179 32.379961, -117.077179 32.721443, -117.284546 32.721443, -117.284546 32.379961))"
polygon_wgs84 = wkt.loads(polygon_wkt)

# Sentinel-2 ID string
s2_id = "20250310T182211_20250310T183049_T11SMR"

# Image files
tif_files = {
    "SAR": "/Volumes/External/TJ_SAR/02_preprocessed/background_gooddays/S1A_IW_GRDH_1SDV_20250310T015010_20250310T015039_058236_07325B_1D4B_pre.tif",
    "RGB": "/Volumes/External/TJ_Optical/images/RGB_2025-3-10.tif",
    "NDCI": "/Volumes/External/TJ_Optical/images/NDCI_2025-3-10.tif",
    "NDTI": "/Volumes/External/TJ_Optical/images/NDTI_2025-3-10.tif"
}

# Outflow point shapefile
outflow_path = "/Volumes/External/TJ_SAR/01_data/shapefiles/Outflow.shp"
outflow_gdf = gpd.read_file(outflow_path).to_crs("EPSG:4326")

# ------------------ FUNCTIONS ------------------

def scale_image(img):
    valid = img[~np.isnan(img)]
    if valid.size == 0:
        return np.zeros_like(img)
    p5, p95 = np.percentile(valid, (5, 95))
    stretched = np.clip((img - p5) / (p95 - p5 + 1e-6), 0, 1)
    stretched[np.isnan(img)] = 0
    return stretched

def project_outflow_to_pixel_coords(gdf, transform, crs):
    gdf_proj = gdf.to_crs(crs)
    coords = []
    for geom in gdf_proj.geometry:
        x, y = geom.x, geom.y
        col, row = ~transform * (x, y)
        coords.append((col, row))
    return coords

def gamma_correct(image, gamma=1.5):
    return np.clip(image ** (1 / gamma), 0, 1)

def extract_sar_datetime(filename):
    basename = os.path.basename(filename)
    match = re.search(r'(\d{8}T\d{6})', basename)
    if match:
        dt_str = match.group(1)
        dt_obj = datetime.strptime(dt_str, "%Y%m%dT%H%M%S")
        return dt_obj.strftime("%Y-%m-%d %H:%M:%S UTC")
    return None

def extract_s2_datetime(s2_id):
    match = re.match(r"(\d{8}T\d{6})", s2_id)
    if match:
        dt_str = match.group(1)
        dt_obj = datetime.strptime(dt_str, "%Y%m%dT%H%M%S")
        return dt_obj.strftime("%Y-%m-%d %H:%M:%S UTC")
    return None

# ------------------ CLIP & LOAD ------------------

clipped_images = {}

for label, path in tif_files.items():
    print(f"\n🟡 Checking {label}: {path}")
    with rasterio.open(path) as src:
        print(f" - CRS: {src.crs}")
        print(f" - Bounds: {src.bounds}")
        print(f" - Band count: {src.count}")

        # Check intersection
        bbox = box(*src.bounds)
        transformer = Transformer.from_crs(src.crs, "EPSG:4326", always_xy=True)
        bbox_wgs84 = transform(transformer.transform, bbox)
        intersects = polygon_wgs84.intersects(bbox_wgs84)
        print(f" - Intersects AOI polygon: {intersects}")

        if not intersects:
            clipped_images[label] = None
            continue

        # Transform polygon to image CRS
        transformer_to_img = Transformer.from_crs("EPSG:4326", src.crs, always_xy=True)
        polygon_img = transform(transformer_to_img.transform, polygon_wgs84)
        geojson_geom = [mapping(polygon_img)]

        try:
            clipped, transform_out = mask(src, geojson_geom, crop=True)
            if np.isnan(clipped).all():
                raise ValueError("Clipped result is all NaNs.")
            print(f"   ✅ Clipped shape: {clipped.shape}")
            clipped_images[label] = (clipped, transform_out, src.crs)
        except Exception as e:
            print(f"   ❌ Failed to clip: {e}")
            clipped_images[label] = None

# ------------------ PLOTTING ------------------

fig, axes = plt.subplots(1, 4, figsize=(16, 4))
plt.subplots_adjust(wspace=0.01, hspace=0)

for ax, (label, data) in zip(axes, clipped_images.items()):
    ax.axis('off')
    if data is None:
        ax.set_title(f"{label} (No data)")
        continue

    clipped, transform_out, image_crs = data

    try:
        if label == "RGB":
            rgb = np.stack([
                scale_image(clipped[0]),
                scale_image(clipped[1]),
                scale_image(clipped[2])], axis=-1)

            rgb = gamma_correct(rgb)
            ax.imshow(rgb)

        else:
            cmap = 'viridis' if label in ["NDCI", "NDTI"] else 'gray'
            scaled = scale_image(clipped[0])
            im = ax.imshow(scaled, cmap=cmap)

            # Add colorbar
            norm = Normalize(vmin=np.nanpercentile(clipped[0], 5), vmax=np.nanpercentile(clipped[0], 95))
            sm = ScalarMappable(norm=norm, cmap=cmap)
            cbar = plt.colorbar(sm, ax=ax, fraction=0.046, pad=0.01)
            cbar.ax.tick_params(labelsize=6)
            cbar.set_label("Backscatter (dB)" if label == "SAR" else label, fontsize=8)

        # Plot outflow point(s)
        outflow_px = project_outflow_to_pixel_coords(outflow_gdf, transform_out, image_crs)
        for col, row in outflow_px:
            ax.plot(col, row, '*', color='orange', markersize=4)

        # Set title
        if label == "SAR":
            obs_time = extract_sar_datetime(tif_files[label])
            title = f"SAR\n{obs_time}" if obs_time else "SAR"
            ax.set_title(title, fontsize=9)
        elif label == "RGB":
            obs_time = extract_s2_datetime(s2_id)
            title = f"RGB\n{obs_time}" if obs_time else "RGB"
            ax.set_title(title, fontsize=9)
        else:
            ax.set_title(label, fontsize=9)
    except Exception as e:
        print(f"⚠️ Plotting error on {label}: {e}")
        ax.set_title(f"{label} (Error)")

plt.show()
# Out:
# 🟡 Checking SAR: /Volumes/External/TJ_SAR/02_preprocessed/background_gooddays/S1A_IW_GRDH_1SDV_20250310T015010_20250310T015039_058236_07325B_1D4B_pre.tif
#  - CRS: EPSG:4326
#  - Bounds: BoundingBox(left=-117.45775188603434, bottom=32.26845117288146, right=-117.00697727646318, top=32.724975000271)
#  - Band count: 2
#  - Intersects AOI polygon: True
#    ✅ Clipped shape: (2, 1902, 1155)
#
# 🟡 Checking RGB: /Volumes/External/TJ_Optical/images/RGB_2025-3-10.tif
#  - CRS: EPSG:4326
#  - Bounds: BoundingBox(left=-117.4191501133763, bottom=32.324258531529566, right=-116.99882839193678, top=32.75976178127071)
#  - Band count: 3
#  - Intersects AOI polygon: True
#    ✅ Clipped shape: (3, 3802, 2309)
#
# 🟡 Checking NDCI: /Volumes/External/TJ_Optical/images/NDCI_2025-3-10.tif
#  - CRS: EPSG:4326
#  - Bounds: BoundingBox(left=-117.4191501133763, bottom=32.324258531529566, right=-116.99882839193678, top=32.75976178127071)
#  - Band count: 1
#  - Intersects AOI polygon: True
# ...

# %%
import os
import pandas as pd
import geopandas as gpd
import rasterio
from rasterio.plot import show
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.patches import Patch
from matplotlib.lines import Line2D
from shapely import wkt

# Paths
original_root = '/Volumes/External/TJ_SAR/02_preprocessed/background_gooddays'
shapefile_dir = '/Volumes/External/TJ_SAR/06_shapefiles/great'
plume_path = '/Volumes/External/TJ_SAR/01_data/shapefiles/plumeExtentv4.shp'
outflow_path = '/Volumes/External/TJ_SAR/01_data/shapefiles/Outflow.shp'
excel_path = '/Volumes/External/TJ_SAR/analysis/Master.xlsx'

# Load input data
df = pd.read_excel(excel_path)
plume_gdf = gpd.read_file(plume_path).to_crs(epsg=4326)
outflow_gdf = gpd.read_file(outflow_path).to_crs(epsg=4326)

# Parse WKT and extract bounding box
wkt_poly = "POLYGON ((-117.16507 32.371843, -117.075806 32.371843, -117.075806 32.603519, -117.16507 32.603519, -117.16507 32.371843))"
polygon = wkt.loads(wkt_poly)
minx, miny, maxx, maxy = polygon.bounds

# Loop through unique basenames
for original_filename in df["original_filename"].drop_duplicates():
    base_name = original_filename
    image_path = os.path.join(original_root, f"{base_name}_pre.tif")
    shapefile_path = os.path.join(shapefile_dir, f"{base_name}_pre_mask.shp")

    # Check image and shapefile exist
    if not os.path.exists(image_path):
        print(f"Image not found: {image_path}")
        continue
    if not os.path.exists(shapefile_path):
        print(f"Shapefile not found: {shapefile_path}")
        continue

    # Find matching manual delineations (plume)
    matching_plume = plume_gdf[plume_gdf["sourceName"] == base_name]

    # Start plot
    with rasterio.open(image_path) as src:
        img = src.read(1).astype(np.float32)
        mask = img > 0
        vmin, vmax = np.percentile(img[mask], (3, 90))

        fig, ax = plt.subplots(figsize=(10, 10))
        show(img, ax=ax, transform=src.transform, cmap='gray', vmin=vmin, vmax=vmax)

        # Plot red: algorithm output
        gdf = gpd.read_file(shapefile_path)
        gdf.plot(ax=ax, facecolor='none', edgecolor='red', linewidth=1, zorder=2)

        # Plot blue dashed: manual delineation
        if not matching_plume.empty:
            matching_plume.plot(ax=ax, facecolor='none', edgecolor='deepskyblue',
                                linewidth=1.5, linestyle='--', zorder=3)

        # Plot yellow: outflow points
        outflow_gdf.plot(ax=ax, color='yellow', edgecolor='black',  markersize=25, zorder=4)

        # Cropping and cleanup
        ax.set_xlim(minx, maxx)
        ax.set_ylim(miny, maxy)
        ax.set_xticks([])
        ax.set_yticks([])
        ax.grid(False)

        # Legend
        legend_elements = [
            Patch(facecolor='none', edgecolor='red', label='algorithm output'),
            Line2D([0], [0], color='deepskyblue', linestyle='--', label='manual delineation'),
            Line2D([0], [0], marker='o', color='yellow', markeredgecolor='black', linestyle='None', markersize=8, label='outflow points')
        ]
        ax.legend(handles=legend_elements, loc='upper right', fontsize='medium', frameon=True)

        # Save figure
        output_dir = "/Volumes/External/TJ_SAR/05_viz/algovspolygon2"
        os.makedirs(output_dir, exist_ok=True)
        output_path = os.path.join(output_dir, f"{base_name}.png")
        plt.savefig(output_path, dpi=300, bbox_inches='tight')
        plt.close()
# Out:
# Shapefile not found: /Volumes/External/TJ_SAR/06_shapefiles/great/S1A_IW_GRDH_1SDV_20230917T015020_20230917T015049_050361_06103C_F092_pre_mask.shp
# Shapefile not found: /Volumes/External/TJ_SAR/06_shapefiles/great/S1A_IW_GRDH_1SDV_20240303T015016_20240303T015045_052811_066417_AE29_pre_mask.shp
# Image not found: /Volumes/External/TJ_SAR/02_preprocessed/background_gooddays/S1A_IW_GRDH_1SDV_20240315T135319_20240315T135344_052993_066A5F_CBC10_pre.tif
# Shapefile not found: /Volumes/External/TJ_SAR/06_shapefiles/great/S1A_IW_GRDH_1SDV_20240403T134457_20240403T134522_053270_0674E8_A9EF_pre_mask.shp
# Shapefile not found: /Volumes/External/TJ_SAR/06_shapefiles/great/S1A_IW_GRDH_1SDV_20240825T134455_20240825T134520_055370_06C0B3_2887_pre_mask.shp
