# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import rasterio
from datetime import datetime
from pytz import timezone, utc
from matplotlib.colors import ListedColormap
from matplotlib.colors import LinearSegmentedColormap
from pytz import timezone

# %%
# --- Parameters ---
original_root = "/Volumes/External/TJ_SAR/02_preprocessed/01_JunethroughDec2024"
mask_root = "/Volumes/External/TJ_SAR/04_iseg"
output_plot_dir = "/Volumes/External/TJ_SAR/05_viz/_20222025"
met_csv_path = "/Volumes/External/TJ_estuary/analysis/TJRTLMET.csv"

# %%
pacific = timezone("US/Pacific")
# --- Load meteorological data (in Pacific Time) ---
met_df = pd.read_csv(met_csv_path)
met_df.columns = met_df.columns.str.strip()

met_df["DateTimeStamp"] = pd.to_datetime(
    met_df["DateTimeStamp"], format="%m/%d/%y %H:%M", errors="coerce"
)
met_df["DateTimeStamp"] = met_df["DateTimeStamp"].dt.tz_localize(
    pacific,
    ambiguous="NaT",     # handle fall-back (ambiguous) times
    nonexistent="NaT"    # handle spring-forward (nonexistent) times
)
met_df = met_df.dropna(subset=["DateTimeStamp"])

met_df = met_df.sort_values("DateTimeStamp")

# %%
def extract_datetime_from_filename(filename):
    """Extract UTC datetime from Sentinel-1 filename."""
    parts = filename.split("_")
    for part in parts:
        if part.startswith("20") and "T" in part:
            try:
                return utc.localize(datetime.strptime(part, "%Y%m%dT%H%M%S"))
            except ValueError:
                continue
    return None

def get_nearest_met_data(local_time):
    """Find the closest met record to the given local time."""
    time_deltas = (met_df["DateTimeStamp"] - local_time).abs()
    nearest_idx = time_deltas.idxmin()
    row = met_df.loc[nearest_idx]
    return row["WSpd"], row["Wdir"], row["DateTimeStamp"]

def match_original_path(mask_filename):
    return os.path.join(original_root, mask_filename.replace("_JPL0.4_VVDR_cumulative_mask.tif", ".tif"))

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import rasterio
import math
from matplotlib.colors import Normalize
import matplotlib.patches as patches

def plot_overlay(original_path, mask_path, output_path):
    # --- Extract and convert image time ---
    image_time_utc = extract_datetime_from_filename(os.path.basename(original_path))
    image_time_local = image_time_utc.astimezone(pacific)

    # --- Match meteorological data ---
    wspd, wdir, met_time = get_nearest_met_data(image_time_local)

    # --- Read images ---
    with rasterio.open(original_path) as src:
        original = src.read(1).astype(float)
        bounds = src.bounds
        extent = [bounds.left, bounds.right, bounds.bottom, bounds.top]

    with rasterio.open(mask_path) as src:
        mask = src.read(1)

    # --- Linear 2–98 percentile stretch ---
    # Compute the 2nd and 98th percentiles and linearly map to [0,1]
    vmin, vmax = np.nanpercentile(original, (2, 95))
    clipped = np.clip(original, vmin, vmax)
    normed = (clipped - vmin) / (vmax - vmin)

    # --- Set up side-by-side figure ---
    fig, axes = plt.subplots(1, 2, figsize=(9, 12), constrained_layout=True)

    # Left: original stretched
    axes[0].imshow(normed, cmap="gray", extent=extent)
    axes[0].set_title("Original (2–98% Stretch)", fontsize=12)
    axes[0].axis('off')

    # Right: original + mask
    axes[1].imshow(normed, cmap="gray", extent=extent)

    # Build RGBA overlay for plume mask
    mask_bin = (mask > 0)
    overlay = np.zeros((mask.shape[0], mask.shape[1], 4))
    overlay[mask_bin] = [1.0, 1.0, 0.8, 1.0]   # light yellow, fully opaque

    axes[1].imshow(overlay, extent=extent)
    axes[1].set_title("Original with Plume Mask", fontsize=12)
    axes[1].axis('off')

    # --- Bottom annotation: wind info + local time ---
    wind_text = (
        f"Wind: {wspd:.1f} m/s @ {wdir:.0f}°\n"
        f"Local Time: {image_time_local.strftime('%Y-%m-%d %H:%M')}"
    )
    fig.text(0.5, 0.15, wind_text, ha='center', fontsize=13, fontweight='bold')

    # --- Wind vector in real coordinates ---
    wind_angle_deg = (270 - wdir) % 360
    angle_rad = math.radians(wind_angle_deg)
    height = bounds.top - bounds.bottom
    base_frac = 0.07
    scale = np.clip(wspd / 10, 0.5, 1.5)
    arrow_length = height * base_frac * scale
    dx = arrow_length * math.cos(angle_rad)
    dy = arrow_length * math.sin(angle_rad)
    x0 = bounds.right - 0.1 * (bounds.right - bounds.left)
    y0 = bounds.bottom + 0.05 * height

    axes[1].add_patch(
        patches.FancyArrow(
            x0, y0, dx, dy,
            width=arrow_length * 0.05,
            head_width=arrow_length * 0.15,
            head_length=arrow_length * 0.15,
            length_includes_head=True,
            transform=axes[1].transData,
            color='lime',
            alpha=0.9
        )
    )

    # --- Save plot ---
    os.makedirs(os.path.dirname(output_path), exist_ok=True)
    plt.savefig(output_path, dpi=150, bbox_inches='tight')
    plt.close()
    print(f"Saved: {output_path}")

# %%
# --- Main processing loop ---
for root, _, files in os.walk(mask_root):
    for file in files:
        if file.startswith('.'):
            continue
        if file.endswith("_JPL0.4_VVDR_cumulative_mask.tif"):
            mask_path = os.path.join(root, file)
            original_path = match_original_path(file)

            if os.path.exists(original_path):
                flat_name = file.replace("_JPL0.4_VVDR_cumulative_mask.tif", "_overlay.png")
                output_path = os.path.join(output_plot_dir, flat_name)
                plot_overlay(original_path, mask_path, output_path)
            else:
                print(f"[!] Original image not found for: {file}")

print("Done!")
# Out:
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20221121T015015_20221121T015044_045986_0580C5_7D6E_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20221121T135317_20221121T135342_045993_058110_4619_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20221128T134454_20221128T134519_046095_05847D_4A73_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20221203T015015_20221203T015044_046161_0586BC_72DC_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20221203T135317_20221203T135342_046168_058705_6F82_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20221210T134454_20221210T134519_046270_058A79_9DD5_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20221215T015014_20221215T015043_046336_058CB1_E040_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20221215T135316_20221215T135341_046343_058CF7_BB7D_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20221222T134453_20221222T134518_046445_059070_AB51_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20221227T015013_20221227T015042_046511_0592AC_6390_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20221227T135315_20221227T135340_046518_0592F4_A111_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20230103T134452_20230103T134517_046620_059664_9029_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20230108T015013_20230108T015042_046686_05988B_7011_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20230108T135315_20230108T135340_046693_0598D3_8F17_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20230905T135322_20230905T135347_050193_060A98_3BE1_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20230912T134459_20230912T134524_050295_060E0D_D68A_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20230917T015020_20230917T015049_050361_06103C_F092_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20230917T135322_20230917T135347_050368_061082_A98C_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20230924T134500_20230924T134525_050470_061400_0602_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20230929T015020_20230929T015050_050536_061636_4053_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20230929T135323_20230929T135348_050543_06167E_9BF0_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20231011T135322_20231011T135347_050718_061C83_5713_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20231018T134500_20231018T134525_050820_062006_A1F1_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20231023T015021_20231023T015050_050886_06222F_3F6B_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20231023T135323_20231023T135348_050893_062276_4D6B_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20231030T134500_20231030T134525_050995_0625F8_4858_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20231104T015020_20231104T015049_051061_062830_C64E_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20231104T135322_20231104T135347_051068_062873_F9A6_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20231111T134459_20231111T134524_051170_062BFB_B1D2_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20231116T015020_20231116T015049_051236_062E3B_CFEA_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20231116T135322_20231116T135347_051243_062E82_50A8_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20231123T134459_20231123T134524_051345_063209_B69F_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20231128T015019_20231128T015048_051411_063445_2DDA_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20231128T135321_20231128T135346_051418_06348D_1B71_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20231205T134459_20231205T134524_051520_06380A_28CB_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20231210T015019_20231210T015048_051586_063A53_9BA8_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20231210T135321_20231210T135346_051593_063A9F_D2E6_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20231217T134458_20231217T134523_051695_063E28_782E_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20231222T015018_20231222T015047_051761_06406D_780F_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20231222T135320_20231222T135345_051768_0640B7_963B_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20231229T134457_20231229T134522_051870_064437_BD64_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20240103T015018_20240103T015047_051936_064669_4FCF_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20240103T135320_20240103T135345_051943_0646B5_90A4_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20240110T134457_20240110T134522_052045_064A30_E134_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20240115T015017_20240115T015046_052111_064C5F_46F6_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20240115T135319_20240115T135344_052118_064CAA_0B68_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20240122T134456_20240122T134521_052220_065012_EEEA_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20240127T015017_20240127T015046_052286_065243_A94A_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20240127T135319_20240127T135344_052293_06528D_FBF7_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20240203T134456_20240203T134521_052395_0655FE_3EE8_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20240208T015016_20240208T015045_052461_06582C_D693_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20240208T135318_20240208T135343_052468_065876_088C_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20240215T134456_20240215T134521_052570_065BE6_1DE0_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20240220T015016_20240220T015045_052636_065E1F_6B77_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20240220T135318_20240220T135343_052643_065E66_115E_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20240227T134456_20240227T134521_052745_0661DD_B8E8_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20240303T015016_20240303T015045_052811_066417_AE29_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20240303T135319_20240303T135344_052818_066462_D424_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20240310T134456_20240310T134521_052920_0667CE_69CD_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20240315T015016_20240315T015045_052986_066A10_8EF8_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20240315T135319_20240315T135344_052993_066A5F_CBC9_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20240322T134456_20240322T134521_053095_066E50_5131_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20240327T015016_20240327T015045_053161_0670C6_52F0_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20240327T135319_20240327T135344_053168_06710F_4BA5_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20240403T134457_20240403T134522_053270_0674E8_A9EF_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20240408T015017_20240408T015046_053336_06778C_DC45_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20240408T135319_20240408T135344_053343_0677DE_627F_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20240415T134456_20240415T134521_053445_067BDA_1687_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20240420T015018_20240420T015047_053511_067E78_8A3A_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20240420T135320_20240420T135345_053518_067EC6_A490_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20240427T134457_20240427T134522_053620_0682BA_7866_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20240502T015018_20240502T015047_053686_068554_1DA9_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20240502T135320_20240502T135345_053693_0685A6_2A5F_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20240509T134457_20240509T134522_053795_068985_CAAC_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20240514T015017_20240514T015046_053861_068BD1_3DC1_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20240514T135319_20240514T135344_053868_068C10_FCF2_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20240521T134457_20240521T134522_053970_068F86_2699_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20240526T015018_20240526T015047_054036_0691D3_5A9C_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20240526T135320_20240526T135345_054043_069216_FC36_pre_JPL0.4_VVDR_cumulative_mask.tif
# Saved: /Volumes/External/TJ_SAR/05_viz/_20222025/S1A_IW_GRDH_1SDV_20241204T135317_20241204T135342_056843_06FAC2_A1E1_pre_overlay.png
# Saved: /Volumes/External/TJ_SAR/05_viz/_20222025/S1A_IW_GRDH_1SDV_20241211T134454_20241211T134519_056945_06FEB3_3558_pre_overlay.png
# Saved: /Volumes/External/TJ_SAR/05_viz/_20222025/S1A_IW_GRDH_1SDV_20241216T015014_20241216T015043_057011_070161_E8F2_pre_overlay.png
# Saved: /Volumes/External/TJ_SAR/05_viz/_20222025/S1A_IW_GRDH_1SDV_20241216T135316_20241216T135341_057018_0701B0_5892_pre_overlay.png
# Saved: /Volumes/External/TJ_SAR/05_viz/_20222025/S1A_IW_GRDH_1SDV_20241223T134453_20241223T134518_057120_0705BE_A61A_pre_overlay.png
# Saved: /Volumes/External/TJ_SAR/05_viz/_20222025/S1A_IW_GRDH_1SDV_20241228T135315_20241228T135340_057193_0708A1_63F7_pre_overlay.png
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20250104T134451_20250104T134516_057295_070C9C_D664_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20250109T015012_20250109T015041_057361_070F36_4B93_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20250109T135314_20250109T135339_057368_070F87_746A_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20250116T134450_20250116T134515_057470_071385_6ECF_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20250121T015002_20250121T015031_057536_071629_F6C4_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20250121T135314_20250121T135339_057543_07167E_5007_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20250128T134450_20250128T134515_057645_071A80_4818_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20250202T015002_20250202T015031_057711_071D19_1729_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20250202T135312_20250202T135337_057718_071D69_4DDB_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20250209T134449_20250209T134514_057820_07216B_85D0_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20250214T015001_20250214T015030_057886_072419_C906_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20250214T135313_20250214T135338_057893_07246C_553C_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20250221T134449_20250221T134514_057995_072886_4FBB_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20250226T015001_20250226T015030_058061_072B37_4E9F_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20250226T135311_20250226T135336_058068_072B83_9A96_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20250305T134449_20250305T134514_058170_072FB3_9406_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20250310T015010_20250310T015039_058236_07325B_1D4B_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20250310T135312_20250310T135337_058243_0732A8_F834_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20250317T134449_20250317T134514_058345_0736A5_A702_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20250322T015002_20250322T015031_058411_073944_A978_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20250322T135312_20250322T135337_058418_073994_EB52_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20250329T134449_20250329T134514_058520_073D9E_3883_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20250403T015002_20250403T015031_058586_074050_2A31_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20250410T134449_20250410T134514_058695_0744C8_BF1E_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20250415T015002_20250415T015031_058761_07477F_A67C_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20250415T135312_20250415T135337_058768_0747CA_CCD9_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20250422T134449_20250422T134514_058870_074BF1_C08C_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20250427T015002_20250427T015031_058936_074EA5_33FC_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20250427T135313_20250427T135338_058943_074EF3_7927_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20250504T134450_20250504T134515_059045_0752F3_19DD_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20250509T015010_20250509T015039_059111_07557C_D41A_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20250509T135312_20250509T135337_059118_0755BD_4653_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20250516T134449_20250516T134514_059220_07593D_9C52_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20250521T135312_20250521T135337_059293_075BCA_5909_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20250528T134449_20250528T134514_059395_075F54_AA7D_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20250602T015009_20250602T015038_059461_07619A_2357_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20250602T135311_20250602T135336_059468_0761DC_3B13_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20250609T134448_20250609T134513_059570_07654D_92AF_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20250614T015008_20250614T015037_059636_07678F_8C4C_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20250614T135311_20250614T135336_059643_0767D2_7651_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1A_IW_GRDH_1SDV_20250621T134447_20250621T134512_059745_076B58_9374_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1C_IW_GRDH_1SDV_20250416T134344_20250416T134409_001919_003BD3_5FB8_pre_JPL0.4_VVDR_cumulative_mask.tif
# [!] Original image not found for: S1C_IW_GRDH_1SDV_20250421T014857_20250421T014922_001985_003FBB_DFC0_pre_JPL0.4_VVDR_cumulative_mask.tif
# Saved: /Volumes/External/TJ_SAR/05_viz/_20222025/S1A_IW_GRDH_1SDV_20241228T135315_20241228T135340_057193_0708A1_63F7_pre_overlay.png
# Saved: /Volumes/External/TJ_SAR/05_viz/_20222025/S1A_IW_GRDH_1SDV_20241228T015013_20241228T015042_057186_070853_6333_pre_overlay.png
# Saved: /Volumes/External/TJ_SAR/05_viz/_20222025/S1A_IW_GRDH_1SDV_20241223T134453_20241223T134518_057120_0705BE_A61A_pre_overlay.png
# Saved: /Volumes/External/TJ_SAR/05_viz/_20222025/S1A_IW_GRDH_1SDV_20241216T135316_20241216T135341_057018_0701B0_5892_pre_overlay.png
# Saved: /Volumes/External/TJ_SAR/05_viz/_20222025/S1A_IW_GRDH_1SDV_20241216T015014_20241216T015043_057011_070161_E8F2_pre_overlay.png
# Saved: /Volumes/External/TJ_SAR/05_viz/_20222025/S1A_IW_GRDH_1SDV_20241211T134454_20241211T134519_056945_06FEB3_3558_pre_overlay.png
# Saved: /Volumes/External/TJ_SAR/05_viz/_20222025/S1A_IW_GRDH_1SDV_20241204T135317_20241204T135342_056843_06FAC2_A1E1_pre_overlay.png
# Saved: /Volumes/External/TJ_SAR/05_viz/_20222025/S1A_IW_GRDH_1SDV_20241204T015015_20241204T015044_056836_06FA75_DFE3_pre_overlay.png
# Saved: /Volumes/External/TJ_SAR/05_viz/_20222025/S1A_IW_GRDH_1SDV_20241129T134455_20241129T134520_056770_06F7DB_D673_pre_overlay.png
# Saved: /Volumes/External/TJ_SAR/05_viz/_20222025/S1A_IW_GRDH_1SDV_20241122T135318_20241122T135343_056668_06F3D6_0258_pre_overlay.png
# Saved: /Volumes/External/TJ_SAR/05_viz/_20222025/S1A_IW_GRDH_1SDV_20241122T015016_20241122T015045_056661_06F388_00D1_pre_overlay.png
# Saved: /Volumes/External/TJ_SAR/05_viz/_20222025/S1A_IW_GRDH_1SDV_20241117T134456_20241117T134521_056595_06F0DF_6AA8_pre_overlay.png
# Saved: /Volumes/External/TJ_SAR/05_viz/_20222025/S1A_IW_GRDH_1SDV_20241110T135319_20241110T135344_056493_06ECD4_BBBF_pre_overlay.png
# Saved: /Volumes/External/TJ_SAR/05_viz/_20222025/S1A_IW_GRDH_1SDV_20241110T015016_20241110T015045_056486_06EC81_800D_pre_overlay.png
# Saved: /Volumes/External/TJ_SAR/05_viz/_20222025/S1A_IW_GRDH_1SDV_20241105T134456_20241105T134521_056420_06E9E3_3EBC_pre_overlay.png
# Saved: /Volumes/External/TJ_SAR/05_viz/_20222025/S1A_IW_GRDH_1SDV_20241029T135319_20241029T135344_056318_06E5E2_52F5_pre_overlay.png
# Saved: /Volumes/External/TJ_SAR/05_viz/_20222025/S1A_IW_GRDH_1SDV_20241029T015017_20241029T015046_056311_06E595_EEAE_pre_overlay.png
# Saved: /Volumes/External/TJ_SAR/05_viz/_20222025/S1A_IW_GRDH_1SDV_20241024T134456_20241024T134521_056245_06E2F3_544C_pre_overlay.png
# Saved: /Volumes/External/TJ_SAR/05_viz/_20222025/S1A_IW_GRDH_1SDV_20241017T135319_20241017T135344_056143_06DEF0_4602_pre_overlay.png
# Saved: /Volumes/External/TJ_SAR/05_viz/_20222025/S1A_IW_GRDH_1SDV_20241017T015017_20241017T015046_056136_06DE9F_4EAA_pre_overlay.png
# Saved: /Volumes/External/TJ_SAR/05_viz/_20222025/S1A_IW_GRDH_1SDV_20241012T134456_20241012T134521_056070_06DC04_4FC8_pre_overlay.png
# Saved: /Volumes/External/TJ_SAR/05_viz/_20222025/S1A_IW_GRDH_1SDV_20241005T135319_20241005T135344_055968_06D804_146E_pre_overlay.png
# Saved: /Volumes/External/TJ_SAR/05_viz/_20222025/S1A_IW_GRDH_1SDV_20241005T015016_20241005T015045_055961_06D7BE_EA54_pre_overlay.png
# Saved: /Volumes/External/TJ_SAR/05_viz/_20222025/S1A_IW_GRDH_1SDV_20240930T134456_20240930T134521_055895_06D520_6A0F_pre_overlay.png
# Saved: /Volumes/External/TJ_SAR/05_viz/_20222025/S1A_IW_GRDH_1SDV_20240923T135318_20240923T135343_055793_06D11E_354B_pre_overlay.png
# Saved: /Volumes/External/TJ_SAR/05_viz/_20222025/S1A_IW_GRDH_1SDV_20240923T015016_20240923T015045_055786_06D0CD_4C0A_pre_overlay.png
# Saved: /Volumes/External/TJ_SAR/05_viz/_20222025/S1A_IW_GRDH_1SDV_20240918T134456_20240918T134521_055720_06CE30_E1E3_pre_overlay.png
# Saved: /Volumes/External/TJ_SAR/05_viz/_20222025/S1A_IW_GRDH_1SDV_20240911T135318_20240911T135343_055618_06CA33_3AB0_pre_overlay.png
# Saved: /Volumes/External/TJ_SAR/05_viz/_20222025/S1A_IW_GRDH_1SDV_20240911T015016_20240911T015045_055611_06C9E7_3B08_pre_overlay.png
# Saved: /Volumes/External/TJ_SAR/05_viz/_20222025/S1A_IW_GRDH_1SDV_20240906T134455_20240906T134520_055545_06C745_BC60_pre_overlay.png
# Saved: /Volumes/External/TJ_SAR/05_viz/_20222025/S1A_IW_GRDH_1SDV_20240830T135318_20240830T135343_055443_06C35B_0F4A_pre_overlay.png
# Saved: /Volumes/External/TJ_SAR/05_viz/_20222025/S1A_IW_GRDH_1SDV_20240830T015015_20240830T015045_055436_06C312_73FC_pre_overlay.png
# Saved: /Volumes/External/TJ_SAR/05_viz/_20222025/S1A_IW_GRDH_1SDV_20240825T134455_20240825T134520_055370_06C0B3_2887_pre_overlay.png
# Saved: /Volumes/External/TJ_SAR/05_viz/_20222025/S1A_IW_GRDH_1SDV_20240818T135318_20240818T135343_055268_06BCE6_480E_pre_overlay.png
# Saved: /Volumes/External/TJ_SAR/05_viz/_20222025/S1A_IW_GRDH_1SDV_20240818T015015_20240818T015044_055261_06BC99_5148_pre_overlay.png
# Saved: /Volumes/External/TJ_SAR/05_viz/_20222025/S1A_IW_GRDH_1SDV_20240813T134454_20240813T134519_055195_06BA35_56BE_pre_overlay.png
# Saved: /Volumes/External/TJ_SAR/05_viz/_20222025/S1A_IW_GRDH_1SDV_20240806T135317_20240806T135342_055093_06B68A_CCC5_pre_overlay.png
# Saved: /Volumes/External/TJ_SAR/05_viz/_20222025/S1A_IW_GRDH_1SDV_20240806T015015_20240806T015044_055086_06B638_CB9C_pre_overlay.png
# Saved: /Volumes/External/TJ_SAR/05_viz/_20222025/S1A_IW_GRDH_1SDV_20240801T134455_20240801T134520_055020_06B3F8_8F59_pre_overlay.png
# Saved: /Volumes/External/TJ_SAR/05_viz/_20222025/S1A_IW_GRDH_1SDV_20240725T135317_20240725T135342_054918_06B074_6D24_pre_overlay.png
# Saved: /Volumes/External/TJ_SAR/05_viz/_20222025/S1A_IW_GRDH_1SDV_20240725T015015_20240725T015044_054911_06B032_3EFF_pre_overlay.png
# Saved: /Volumes/External/TJ_SAR/05_viz/_20222025/S1A_IW_GRDH_1SDV_20240720T134455_20240720T134520_054845_06ADDF_F02B_pre_overlay.png
# Saved: /Volumes/External/TJ_SAR/05_viz/_20222025/S1A_IW_GRDH_1SDV_20240713T135318_20240713T135343_054743_06AA5A_62DC_pre_overlay.png
# Saved: /Volumes/External/TJ_SAR/05_viz/_20222025/S1A_IW_GRDH_1SDV_20240713T015016_20240713T015045_054736_06AA18_48C2_pre_overlay.png
# Saved: /Volumes/External/TJ_SAR/05_viz/_20222025/S1A_IW_GRDH_1SDV_20240708T134455_20240708T134520_054670_06A7D2_713E_pre_overlay.png
# Saved: /Volumes/External/TJ_SAR/05_viz/_20222025/S1A_IW_GRDH_1SDV_20240701T135318_20240701T135343_054568_06A44B_57BB_pre_overlay.png
# Saved: /Volumes/External/TJ_SAR/05_viz/_20222025/S1A_IW_GRDH_1SDV_20240701T015016_20240701T015045_054561_06A407_78C1_pre_overlay.png
# Saved: /Volumes/External/TJ_SAR/05_viz/_20222025/S1A_IW_GRDH_1SDV_20240626T134456_20240626T134521_054495_06A1B9_8996_pre_overlay.png
# Saved: /Volumes/External/TJ_SAR/05_viz/_20222025/S1A_IW_GRDH_1SDV_20240619T135319_20240619T135344_054393_069E33_8C28_pre_overlay.png
# Saved: /Volumes/External/TJ_SAR/05_viz/_20222025/S1A_IW_GRDH_1SDV_20240619T015017_20240619T015046_054386_069DEF_1E63_pre_overlay.png
# Saved: /Volumes/External/TJ_SAR/05_viz/_20222025/S1A_IW_GRDH_1SDV_20240614T134456_20240614T134521_054320_069BA3_E195_pre_overlay.png
# Saved: /Volumes/External/TJ_SAR/05_viz/_20222025/S1A_IW_GRDH_1SDV_20240607T135319_20240607T135344_054218_069828_6D52_pre_overlay.png
# Saved: /Volumes/External/TJ_SAR/05_viz/_20222025/S1A_IW_GRDH_1SDV_20240602T134457_20240602T134522_054145_069598_F5E2_pre_overlay.png
# Done!
